# %% [markdown]
# # Covid Owid dataset exploration

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import matplotlib
#       2 print(matplotlib.__version__)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import sys
print('executable:', sys.executable)
print('sys.path:')
for p in sys.path:
    print('-', p)
# Out:
# executable: /opt/anaconda3/envs/python-starter/bin/python
# sys.path:
# - /opt/anaconda3/envs/python-starter/lib/python313.zip
# - /opt/anaconda3/envs/python-starter/lib/python3.13
# - /opt/anaconda3/envs/python-starter/lib/python3.13/lib-dynload
# -
# - /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.25 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (26.0)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 397.8 kB/s  0:00:22m0:00:0100:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 334.2 kB/s  0:00:08 eta 0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 370.3 kB/s  0:00:12m0:00:0100:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.3.0 pyparsing-3.3.2

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.11.0

# %%
import sys
print('kernel executable:', sys.executable)
# !{sys.executable} -m pip install seaborn matplotlib
# Out:
# kernel executable: /opt/anaconda3/envs/python-starter/bin/python
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (3.11.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns

# %%
import sys
print('kernel executable:', sys.executable)
# !{sys.executable} -m pip install plotly
# Out:
# kernel executable: /opt/anaconda3/envs/python-starter/bin/python
# Collecting plotly
#   Downloading plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/python-starter/lib/python3.13/site-packages (from plotly) (26.0)
# Downloading plotly-6.9.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 320.1 kB/s  0:00:30m0:00:0100:02
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Installing collected packages: narwhals, plotly
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]2m1/2 [plotly]
# Successfully installed narwhals-2.24.0 plotly-6.9.0

# %%
import plotly.express as px
